# %%
import sys
sys.path.insert(1, "../..")

import pandas as pd
import numpy as np
import time
from tqdm import tqdm
import kagglehub
import re
import random

from utils import bipartite
from utils import llm_api
from tasks.db import db_utils

# %%
# Ollama service port
PORT="11446"

# %% [markdown]
# We load different datasets here

# %% [markdown]
# ### Adults

# %%
from sklearn.datasets import fetch_openml
# ADULTS
# Fetch the dataset
df = fetch_openml(data_id=1590, as_frame=True).frame

# Display the first few rows
df.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18        NaN  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country  class
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class'],
#       dtype='object')

# %%
df = df[["workclass", "education", "marital-status", "race"]]
df.head()

# %% [markdown]
# ### IMDB

# %%
# Download latest version
path = kagglehub.dataset_download("harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows")

imdb = pd.read_csv(path + "/imdb_top_1000.csv")
imdb = imdb[["Series_Title", "Genre", "IMDB_Rating", "Meta_score", "No_of_Votes"]]
imdb.head()
# Out:
#                Series_Title                 Genre  IMDB_Rating  Meta_score  \
# 0  The Shawshank Redemption                 Drama          9.3        80.0
# 1             The Godfather          Crime, Drama          9.2       100.0
# 2           The Dark Knight  Action, Crime, Drama          9.0        84.0
# 3    The Godfather: Part II          Crime, Drama          9.0        90.0
# 4              12 Angry Men          Crime, Drama          9.0        96.0
#
#    No_of_Votes
# 0      2343110
# 1      1620367
# 2      2303232
# 3      1129952
# 4       689845

# %%
imdb["High_Rated"] = imdb["IMDB_Rating"] > 8.2
imdb["High_Rated"].value_counts()
# Out:
# High_Rated
# False    872
# True     128
# Name: count, dtype: int64

# %% [markdown]
# ### Course Enrollment

# %%
path = kagglehub.dataset_download("anlgrbz/student-demographics-online-education-dataoulad")

enroll = pd.read_csv(path + "/studentRegistration.csv")
enroll.head()
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
enroll.shape
# Out:
# (32593, 5)

# %%
enroll["code_module"].value_counts()
# Out:
# code_module
# BBB    7909
# FFF    7762
# DDD    6272
# CCC    4434
# EEE    2934
# GGG    2534
# AAA     748
# Name: count, dtype: int64

# %% [markdown]
# ### Implementations

# %% [markdown]
# Choosing a column and its corresponding value, we ask a query "Count the number of rows with 'col' equal to 'value'."

# %%
# COLUMN = "workclass" # Adults
# VALUE = "Private" # Adults
# COLUMN = "High_Rated" # IMDB
# VALUE = "True" # IMDB

COLUMN = "code_module"
VALUE = "EEE"

df = enroll

CHUNK_SIZE = 4

# %% [markdown]
# Implementation for Warm-up algorithm

# %%
def get_related_rows(chunk, question, model):
    prompt = "Consider the following dataset as a table:\n" + chunk.to_string()
    query = f"Give me the list of indices of the rows that are related to this query with no further explanation. query: '{question}'"
    return llm_api.ask(
        questions=[
            prompt, query
        ],
        model=model,
        port=PORT
    )

def run_warmup(df, row_indices, result_dict, column, value, model):
    random.shuffle(row_indices)

    chs = []
    for h in range(len(row_indices) // CHUNK_SIZE):
        chs.append(row_indices[h * CHUNK_SIZE: (h + 1) * CHUNK_SIZE])

    question = f"What is the number of rows with column '{column}' equal to '{value}'?"
    reg = r'\d+'

    related = []
    not_related = []

    for ch in chs:
        print("chunk: ", ch)
        time.sleep(0.5)

        def get_res():
            result = get_related_rows(df.iloc[ch].reset_index(drop=True), question, model)
            print("[Naive] related row indices: ", result[:20])
            tmp = [eval(x[0]) for x in re.findall(reg, result)]
            return tmp

        rel_inds = get_res()

        counter = 0
        if len(rel_inds) > len(ch):
            rel_inds = []

        if counter == 10:
            print("Many errors, default setting!")
            rel_inds = []
        
        rel_inds = [i for i in rel_inds if i < len(ch)]
        non_rel = list(filter(lambda x: x not in rel_inds, np.arange(len(ch))))

        related.extend([ch[i] for i in rel_inds])
        not_related.extend([ch[i] for i in non_rel])

    final_rows = related + not_related
    final_rows = final_rows[:len(row_indices)]

    result_dict["reordered"].append(final_rows)
    result_dict["original"].append(row_indices)
    result_dict["algorithm"].append("warmup")
    result_dict["model"].append(model)
    result_dict["size"].append(len(row_indices))
    result_dict["column"].append(column)
    result_dict["value"].append(value)

# %%
run_warmup(
    df.iloc[0:20].reset_index(drop=True),
    row_indices=np.arange(20),
    result_dict=None,
    column="workclass",
    value="Private",
    model="qwen2:7b"
)

# %% [markdown]
# Implementation for Bigraph algorithm

# %%
k = 4 # Shuffles
m = 5 # Batch size

def build_prompt_for_scores(batch_df, query):
    return [
        "Consider the following dataset table: \n" + batch_df.to_string(),
        f"Consider this question on the previous table. question: {query}\n" +
        "Give me a list of scores of length 5 that shows how much each row of the table is relevant (or important) in answering the query. " + 
        "A score is an integer between 0 to 10. 10 means relevant and 0 means not relevant. " +
        "Your answer should contain a list of 5 scores. The order of scores should be the same as order of rows."
    ]

def extract_number_lists(text):
    # Regex pattern to match exactly 5 numbers (comma-separated or not)
    # pattern = r'(\b(\d+\s*,?\s*){4}\d+\b)'
    # pattern = r'(\b(10|[0-9])(,?\s?(10|[0-9])){4}\b)'
    pattern = r'(\b(10|[0-9])([,\s]+(10|[0-9])){4}\b)'
    
    # Find all matches in the given text
    matches = re.findall(pattern, text)
    
    if len(matches) == 0:
        print("NO LIST IN OUTPUT")
        return None
    
    return matches[0][0]

def ask_score(input_batch, query, model, df, column, value):
    def askit():
        prompt = build_prompt_for_scores(df.iloc[input_batch].reset_index(drop=True), query)
        answer = llm_api.ask(questions=prompt, model=model, port=PORT)
        # print("------------\n", answer, "\n--------------")
        return answer


    print(df.iloc[input_batch].reset_index(drop=True)[column].to_list())
    answer = askit()
    # p1 = r"(\s*\d+\s*)"
    # p2 = r"(,(\s*\d+\s*))+"
    number = r'\d+'
    pattern = r"\b(\d+\s*,?\s*){4}\d+\b"
    counter = 0
    while (len(re.findall(pattern, answer)) == 0) and counter < 5:
        print("Retrying...")
        counter += 1
        answer = askit()

    if counter == 5:
        answer = ['0'] * len(input_batch)
        print("FAILED, return zeros")
    else:
        answer = extract_number_lists(answer)
        print("[BI_GRAPH]", answer, input_batch, query)
        answer = re.findall(number, answer)

    # pattern = "(" + p1 + (len(input_batch) - 1) * p2 + ")"
    # for line in answer.split("\n"):
    #     if len(re.findall(pattern, line)) > 0:
    #         answer = re.findall(pattern, line)
    #         break
    numbers = [llm_api.take_out_number(a) for a in answer]
    return [10 if num > 10 else (0 if num < 0 else num) for num in numbers]

def run_bigraph(df, row_indices, result_dict, column, value, model):
    random.shuffle(row_indices)

    question = f"What is the count of rows with column '{column}' equal to '{value}'?"
    
    def ask_score_local(input_batch, query):
        return ask_score(input_batch, query, model=model, df=df, column=column, value=value)
    
    g, element_nodes = bipartite.create_bi_graph(k=k, m=m, prompt=row_indices, query=question, ask_score=ask_score_local)
    bipartite.learn_bi_graph(g, k, m)
    new_prompt = sorted(row_indices, key=lambda x: element_nodes[x].payload, reverse=True)
    
    result_dict["reordered"].append(new_prompt)
    result_dict["original"].append(row_indices)
    result_dict["algorithm"].append("bigraph")
    result_dict["model"].append(model)
    result_dict["size"].append(len(row_indices))
    result_dict["column"].append(column)
    result_dict["value"].append(value)

# %%
run_bigraph(
    df.iloc[0:60].reset_index(drop=True),
    row_indices=np.arange(60),
    result_dict=None,
    column="workclass",
    value="Self-emp-not-inc",
    model="mistral:7b"
)

# %% [markdown]
# Random (lower bound)

# %%
def run_random(df, row_indices, result_dict, column, value):
    random.shuffle(row_indices)

    result_dict["reordered"].append(row_indices)
    result_dict["original"].append(row_indices)
    result_dict["algorithm"].append("random")
    result_dict["model"].append(np.nan)
    result_dict["size"].append(len(row_indices))
    result_dict["column"].append(column)
    result_dict["value"].append(value)

# %% [markdown]
# Optimum (upper bound)

# %%
def run_opt(df, row_indices, result_dict, column, value):
    
    def get_value(index):
        return 1 if df.iloc[index][column] == value else 0
    
    sorted_indices = sorted(row_indices, key=get_value, reverse=True)
    
    result_dict["reordered"].append(sorted_indices)
    result_dict["original"].append(row_indices)
    result_dict["algorithm"].append("opt")
    result_dict["model"].append(np.nan)
    result_dict["size"].append(len(row_indices))
    result_dict["column"].append(column)
    result_dict["value"].append(value)

# %%
run_opt(
    df=df.iloc[20:40].reset_index(drop=True),
    row_indices=np.arange(20),
    result_dict=None,
    column="workclass",
    value="Self-emp-not-inc"
)
# Out:
# [5, 9, 11, 12, 0, 1, 2, 3, 4, 6, 7, 8, 10, 13, 14, 15, 16, 17, 18, 19]

# %% [markdown]
# ### Experiment 1

# %% [markdown]
# - Get rankings from different opensource models and calculate the ranking utility.

# %%
SAMPLES = 10 # This takes one hour!
MODELS = [
    "gemma2:9b",
    "llama3.1:8b",
    "mistral:7b",
    "qwen2:7b",
    "deepseek-coder-v2:16b"
]
SIZE = 100

model = MODELS[4]

COLUMN = "code_module"
VALUES = ["EEE"]

final_result = {
    "algorithm": [],
    "original": [],
    "reordered": [],
    "model": [],
    "size": [],
    "column": [],
    "value": []
}

for sample in range(SAMPLES):
    row_indices = df.sample(n=SIZE).index

    def get_copy(indices):
        return np.array(indices.tolist())
    
    for value in VALUES:
        print(f"{value} | {sample + 1} / {SAMPLES}")

        # Run Random
        print("Running random...")
        run_random(
            df=df,
            row_indices=get_copy(row_indices),
            result_dict=final_result,
            column=COLUMN,
            value=value
        )

        # Run Optimum
        print("Running optimum...")
        run_opt(
            df=df,
            row_indices=get_copy(row_indices),
            result_dict=final_result,
            column=COLUMN,
            value=value
        )

        # Run Warmup
        print("Running warmup...")
        run_warmup(
            df=df,
            row_indices=get_copy(row_indices),
            result_dict=final_result,
            column=COLUMN,
            value=value,
            model=model
        )

        # Run Bigraph
        print("Run Bigraph...")
        run_bigraph(
            df=df,
            row_indices=get_copy(row_indices),
            result_dict=final_result,
            column=COLUMN,
            value=value,
            model=model
        )


final_result = pd.DataFrame(final_result)
# Out:
# EEE | 1 / 10
# Running random...
# Running optimum...
# Running warmup...
# chunk:  [25161 27698 31767 11460]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [  885 22687  3098 25297]
# [Naive] related row indices:   There are no rows i
# chunk:  [27722 16112  2909 14842]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 8262 21530 29394 29263]
# [Naive] related row indices:   To find the number
# chunk:  [23144 25071 28972    25]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 6683 13568 13426 15489]
# [Naive] related row indices:   The question asks f
# chunk:  [17647  4114 21757 28858]
# [Naive] related row indices:   The number of rows
# chunk:  [28691 12019  5887 20995]
# [Naive] related row indices:   The number of rows
# chunk:  [15992  9217  8966 27595]
# [Naive] related row indices:   There are no rows i
# chunk:  [16645 31791 13324 28082]
# [Naive] related row indices:   The provided datase
# chunk:  [ 4065  1088 29737  2226]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 4175 12751  6398  2818]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [20484  4347  8604   139]
# [Naive] related row indices:   The number of rows
# chunk:  [13038 15571  7051  2506]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [21408 19669 19015  1713]
# [Naive] related row indices:   The number of rows
# chunk:  [ 6441 31875   842 18668]
# [Naive] related row indices:   The provided datase
# chunk:  [8758  146 6289 6763]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 8852 25306  3683 19685]
# [Naive] related row indices:   The number of rows
# chunk:  [13909 30207 25079 14249]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [23912 31629  2362  8395]
# [Naive] related row indices:   There are no rows i
# chunk:  [25228 31217 21894  8369]
# [Naive] related row indices:   The number of rows
# chunk:  [ 2267 17299 31514 11447]
# [Naive] related row indices:   The provided datase
# chunk:  [18090 25045  9936 27005]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 2378  8079 25894  1922]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [16379  7354 32340   961]
# [Naive] related row indices:   There are no rows i
# Run Bigraph...
# [BI_GRAPH] For query: What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 1 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['BBB', 'FFF', 'DDD', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7354 28858 17299 25079 14842] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['FFF', 'BBB', 'BBB', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27595  3098  2267   842 15489] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['FFF', 'DDD', 'CCC', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25071 16112  9217   961  8395] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['DDD', 'FFF', 'EEE', 'EEE', 'FFF']
# [BI_GRAPH] 0, 0, 10, 10, 0 [15992 23912 21894 21408 27005] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['EEE', 'FFF', 'BBB', 'BBB', 'GGG']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20995 27722  2378  5887 31514] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['CCC', 'DDD', 'BBB', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [12019 18090  7051  1922 27698] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['AAA', 'BBB', 'CCC', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 139  885 9936 6398 2909] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['FFF', 'BBB', 'EEE', 'GGG', 'BBB']
# [BI_GRAPH] 1, 5, 10, 0, 5 [25306  1713 19669 31791  8604] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['DDD', 'DDD', 'GGG', 'GGG', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14249 13324 30207 31629 31217] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['BBB', 'DDD', 'DDD', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2506 13568 13909  4347 17647] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['FFF', 'GGG', 'DDD', 'EEE', 'CCC']
# [BI_GRAPH] 0, 0, 0, 10, 0 [25045 31767 13426 19685 11447] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['BBB', 'AAA', 'BBB', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8369   146  6289  3683 16379] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['BBB', 'CCC', 'DDD', 'BBB', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [ 4065 11460 16645  6683 20484] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['FFF', 'FFF', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22687 29737  2818  2226  8079] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['AAA', 'BBB', 'DDD', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [   25  4175 19015 28972  8262] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['CCC', 'FFF', 'FFF', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8852 23144 25297  8758 25228] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['FFF', 'BBB', 'DDD', 'BBB', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25894  4114 15571  6763 31875] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['BBB', 'FFF', 'FFF', 'EEE', 'EEE']
# [BI_GRAPH] 0, 0, 0, 10, 10 [ 1088 28082 29394 21757 21530] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['BBB', 'BBB', 'FFF', 'CCC', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2362  6441 29263 12751  8966] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['CCC', 'FFF', 'FFF', 'DDD', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13038 25161 28691 18668 32340] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['DDD', 'DDD', 'FFF', 'CCC', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14249 16379 25045  9217 31629] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['GGG', 'FFF', 'BBB', 'GGG', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31791 27722  4114 31767 30207] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['FFF', 'BBB', 'EEE', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [25894   842 19685 14842  2362] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['BBB', 'BBB', 'BBB', 'FFF', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [ 2226  5887  8079 25071 20995] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['CCC', 'DDD', 'BBB', 'CCC', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8758 16112  3683 13038  9936] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['EEE', 'DDD', 'DDD', 'BBB', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [19669 17647 13426  2909 29394] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['FFF', 'CCC', 'CCC', 'AAA', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25079 12751  8966   146  1088] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['BBB', 'BBB', 'DDD', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 3098  2818 16645 28972 22687] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['CCC', 'DDD', 'BBB', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [11447 15489  4175 27595 15992] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['GGG', 'BBB', 'BBB', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31514  4065  7051 27698  2267] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['FFF', 'FFF', 'FFF', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [28691 23912 25228  2506 28858] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['EEE', 'GGG', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 10, 0, 0, 0, 0 [21757 32340  6763  1922   885] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['DDD', 'DDD', 'BBB', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13568 13324   961 19015 27005] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['FFF', 'BBB', 'BBB', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25161  8395  6289 29737 25306] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['BBB', 'DDD', 'AAA', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8262 13909    25 18668  7354] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['GGG', 'BBB', 'BBB', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31217  4347  2378  6441 28082] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['EEE', 'EEE', 'DDD', 'FFF', 'BBB']
# [BI_GRAPH] 10, 10, 0, 0, 0 [21530 21894 17299 29263  8604] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['FFF', 'CCC', 'DDD', 'AAA', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25297 12019 18090   139  1713] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['BBB', 'FFF', 'GGG', 'CCC', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6683 23144 31875  8852 15571] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['BBB', 'BBB', 'EEE', 'EEE', 'CCC']
# [BI_GRAPH] 0, 0, 10, 10, 0 [ 6398  8369 20484 21408 11460] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['DDD', 'DDD', 'CCC', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [17647 16645 13038 29394 27698] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['GGG', 'FFF', 'DDD', 'EEE', 'AAA']
# [BI_GRAPH] 0, 0, 0, 10, 0 [31514 22687 15571 19669   139] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['BBB', 'GGG', 'EEE', 'CCC', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [ 1088 32340 21894 11447  5887] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['FFF', 'DDD', 'BBB', 'BBB', 'DDD']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [25045 13909  3683  7354 13568] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['CCC', 'FFF', 'GGG', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [11460 28082 31791  2378  4347] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['GGG', 'CCC', 'BBB', 'BBB', 'CCC']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [31217  8852  6289  2506  9217] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['EEE', 'FFF', 'DDD', 'FFF', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 0 [21530 25071 15992 25161  8758] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['EEE', 'BBB', 'FFF', 'BBB', 'EEE']
# [BI_GRAPH] 10, 0, 0, 10, 10 [20995  2267 25306  1713 21408] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['AAA', 'BBB', 'DDD', 'CCC', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  146  8369 16379 12751 12019] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['BBB', 'FFF', 'BBB', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6441 25297  2909  6763 25079] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['FFF', 'FFF', 'FFF', 'BBB', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [27005 23912 28858  8262 20484] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['BBB', 'DDD', 'BBB', 'BBB', 'GGG']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [ 2226 13426  4175   885 31875] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['BBB', 'DDD', 'BBB', 'BBB', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2226 13426  4175   885 31875] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['FFF', 'DDD', 'CCC', 'EEE', 'BBB']
# [BI_GRAPH] 8, 6, 7, 10, 5 [28972 15489  9936 19685  3098] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['DDD', 'BBB', 'BBB', 'DDD', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14842  4065   961 18668 30207] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['BBB', 'FFF', 'FFF', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  842 29263 23144 27722 14249] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['BBB', 'DDD', 'DDD', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8604 17299 16112  1922 29737] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['BBB', 'AAA', 'CCC', 'GGG', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8079    25  8966 31767  6683] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['BBB', 'FFF', 'DDD', 'EEE', 'BBB']
# [BI_GRAPH] 0, 0, 0, 10, 0 [ 6398 28691 19015 21757  8395] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['BBB', 'BBB', 'GGG', 'BBB', 'FFF']
# [BI_GRAPH] 10, 10, 10, 10, 10 [ 4114  7051 31629  2818 25894] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['BBB', 'FFF', 'FFF', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2362 27595 25228 13324 18090] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['CCC', 'GGG', 'BBB', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8966 31875  2909 25161  7051] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['GGG', 'FFF', 'FFF', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [32340 27005 25306  6763  4347] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'DDD', 'AAA', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13909 16645   139  2818  8262] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['BBB', 'CCC', 'EEE', 'EEE', 'FFF']
# [BI_GRAPH] 0, 0, 10, 10, 0 [ 8604 11447 21894 21757 28858] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['BBB', 'AAA', 'AAA', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7354   146    25   961 18668] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['CCC', 'DDD', 'FFF', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 9936 17299 28082 13426  1088] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['FFF', 'BBB', 'GGG', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [29737  2267 31217 18090  6398] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['FFF', 'BBB', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22687  8369  1922  4114 12751] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['BBB', 'FFF', 'FFF', 'CCC', 'CCC']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 4065 25894 28972  9217  8758] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['BBB', 'GGG', 'FFF', 'CCC', 'BBB']
# [BI_GRAPH] 2, 3, 4, 5, 6 [ 4175 31629 25079 11460  6441] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['GGG', 'BBB', 'DDD', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31514  6683 14842 15489 27698] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['GGG', 'FFF', 'FFF', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [30207 28691 29263 13324  3683] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['FFF', 'FFF', 'BBB', 'FFF', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [23144 27595  2226 23912 21408] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['GGG', 'DDD', 'FFF', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31791 19015 27722 14249  2378] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['DDD', 'BBB', 'BBB', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16379  6289  1713  3098 25045] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['EEE', 'FFF', 'EEE', 'CCC', 'FFF']
# [BI_GRAPH] 10, 0, 10, 0, 0 [20995 25228 21530  8852 25297] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['GGG', 'DDD', 'CCC', 'EEE', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31767 13568 13038 19669  2506] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['BBB', 'BBB', 'EEE', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 5887  8395 20484  8079 15571] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['DDD', 'DDD', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [15992 16112   885   842 12019] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['FFF', 'EEE', 'DDD', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25071 19685 17647 29394  2362] What is the count of rows with column 'code_module' equal to 'EEE'?
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: overflow encountered in scalar add
#   b_j += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: divide by zero encountered in scalar divide
#   b_j += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: overflow encountered in scalar divide
#   b_j += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: overflow encountered in scalar add
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: divide by zero encountered in scalar divide
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: overflow encountered in scalar divide
#   y_i += targets_all[target] / g.node_map[target].payload
# EEE | 2 / 10
# Running random...
# Running optimum...
# Running warmup...
# chunk:  [11445 10006 23089  9728]
# [Naive] related row indices:   There are no rows i
# chunk:  [10936 24946 16577 25432]
# [Naive] related row indices:   The provided datase
# chunk:  [ 5962 32580 13199 20134]
# [Naive] related row indices:   The query asks for
# chunk:  [20420 22243  9322  8265]
# [Naive] related row indices:   The number of rows
# chunk:  [18655 15050 22532 17667]
# [Naive] related row indices:   There are no rows i
# chunk:  [25532  5170 16433 32040]
# [Naive] related row indices:   To answer your quer
# chunk:  [ 8134   937   623 16869]
# [Naive] related row indices:   There are 0 rows wh
# chunk:  [15035 19856  6549 11298]
# [Naive] related row indices:   The number of rows
# chunk:  [15565 31094  7972 31271]
# [Naive] related row indices:   The provided datase
# chunk:  [25631  1556 29246 22890]
# [Naive] related row indices:   The provided datase
# chunk:  [10587  6552 17445 14324]
# [Naive] related row indices:   There are no rows i
# chunk:  [1130 5896 9344 8805]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [32255  4961 23362  3565]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [21389 22433 29213 24511]
# [Naive] related row indices:   The number of rows
# chunk:  [17304  7869 13153 26240]
# [Naive] related row indices:   The provided datase
# chunk:  [  321 30900  8536 27287]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 4426  8812 23860 18547]
# [Naive] related row indices:   There are no rows i
# chunk:  [25544 22042 27912 20234]
# [Naive] related row indices:   The list of indices
# chunk:  [ 8970 31334 23776 23355]
# [Naive] related row indices:   To answer your quer
# chunk:  [ 2859 18710  3233 26610]
# [Naive] related row indices:   The dataset provide
# chunk:  [10509  1121 20880 12265]
# [Naive] related row indices:   The number of rows
# chunk:  [10397 12357 32218 18832]
# [Naive] related row indices:   The provided datase
# chunk:  [30200 11661  5229  2418]
# [Naive] related row indices:   There are no rows i
# chunk:  [24868 32301 27773    11]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [ 8729  6000 10714 17928]
# [Naive] related row indices:   The provided datase
# Run Bigraph...
# [BI_GRAPH] For query: What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 1 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['FFF', 'CCC', 'GGG', 'DDD', 'BBB']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [29213 12357 31094 16433  7869] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['DDD', 'CCC', 'GGG', 'AAA', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [18832  9344 31271    11 18710] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['FFF', 'DDD', 'EEE', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 10, 0 [25532 15050 20134 10936  8536] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['FFF', 'DDD', 'GGG', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [23362 18655 32301 31334 17928] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['FFF', 'CCC', 'FFF', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25544  8805 22433 17667 24946] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['FFF', 'EEE', 'CCC', 'FFF', 'CCC']
# [BI_GRAPH] 0, 10, 0, 0, 0 [27773 21389 11298 25432 10006] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['DDD', 'BBB', 'CCC', 'BBB', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13199  3233 12265  7972 32255] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['BBB', 'DDD', 'BBB', 'FFF', 'FFF']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6552 15035  8265 24868 29246] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['CCC', 'BBB', 'DDD', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10397  6549 18547  4961  5229] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['FFF', 'BBB', 'FFF', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22532  8134 23776 27287 17304] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['FFF', 'BBB', 'FFF', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [23089  5896 26610  9322  3565] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['CCC', 'BBB', 'FFF', 'EEE', 'DDD']
# [BI_GRAPH] 0, 0, 0, 10, 0 [11661  2418 25631 20880 16577] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['EEE', 'CCC', 'AAA', 'CCC', 'CCC']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [20234  8970   321 10714  8812] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['EEE', 'CCC', 'AAA', 'CCC', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20234  8970   321 10714  8812] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['DDD', 'BBB', 'CCC', 'GGG', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16869  1130 11445 32580  1556] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['CCC', 'BBB', 'DDD', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10587  4426 15565 17445 14324] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['FFF', 'FFF', 'CCC', 'GGG', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [24511 26240  9728 30200 30900] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['FFF', 'FFF', 'EEE', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [23355 23860 20420 13153  2859] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['AAA', 'BBB', 'EEE', 'FFF', 'GGG']
# [BI_GRAPH] 0, 0, 10, 0, 0 [  623   937 19856 22890 32218] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['FFF', 'GGG', 'BBB', 'EEE', 'EEE']
# [BI_GRAPH] 0, 0, 0, 10, 10 [27912 32040  6000 22243 22042] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['BBB', 'BBB', 'CCC', 'CCC', 'BBB']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [ 5962  5170 10509  8729  1121] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['BBB', 'BBB', 'CCC', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 5962  5170 10509  8729  1121] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['FFF', 'CCC', 'DDD', 'CCC', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [24946 10936 18832 11661 13199] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['GGG', 'BBB', 'CCC', 'DDD', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [31334  6549 11445 16869 19856] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'CCC', 'DDD', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [17667 10006 13153  1130  9728] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['BBB', 'BBB', 'CCC', 'DDD', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7972  5229 12265 17304 32301] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['DDD', 'FFF', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [17445 25544  3233  6000 10509] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['CCC', 'CCC', 'EEE', 'EEE', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [ 8805 12357 20234 22243  2859] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['CCC', 'BBB', 'CCC', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [8970 8134 8729 7869 4426] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['GGG', 'EEE', 'AAA', 'CCC', 'EEE']
# [BI_GRAPH] 0, 10, 0, 0, 10 [32040 20134    11 10714 22042] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['GGG', 'CCC', 'EEE', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [32218 11298 20420 27773  8265] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['BBB', 'FFF', 'DDD', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  937 27287 18655 32255 18710] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['GGG', 'EEE', 'BBB', 'FFF', 'CCC']
# [BI_GRAPH] 0, 10, 0, 0, 0 [30900 20880  3565 23355 10397] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['FFF', 'AAA', 'FFF', 'FFF', 'GGG']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [22433   623 22890 26610 31271] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['FFF', 'AAA', 'FFF', 'FFF', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22433   623 22890 26610 31271] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['CCC', 'AAA', 'CCC', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10587   321  9322  4961 29213] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['FFF', 'FFF', 'CCC', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [26240 25631  9344  5170  1121] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['DDD', 'DDD', 'FFF', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [15565 15050 29246 27912  1556] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['BBB', 'EEE', 'BBB', 'FFF', 'CCC']
# [BI_GRAPH] 3, 4, 0, 0, 0 [ 5896 21389  6552 23860  8812] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['FFF', 'BBB', 'BBB', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [24511  5962  8536 24868 16577] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['FFF', 'DDD', 'DDD', 'GGG', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [23776 18547 17928 30200 25432] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['FFF', 'FFF', 'BBB', 'FFF', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [23089 25532  2418 22532 32580] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['GGG', 'FFF', 'DDD', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31094 23362 16433 15035 14324] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['AAA', 'BBB', 'FFF', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  623  8134 23362 11298 23776] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['CCC', 'EEE', 'BBB', 'GGG', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [10936 22243  6549 32301  2859] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'CCC', 'BBB', 'CCC', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13153 10587  5229  9344 31094] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['GGG', 'FFF', 'CCC', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [32218 27287  8805 25432 25532] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['BBB', 'GGG', 'AAA', 'DDD', 'AAA']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6552 31334   321 17304    11] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['DDD', 'FFF', 'BBB', 'BBB', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [16577 26610  5896  2418 20134] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['CCC', 'EEE', 'BBB', 'BBB', 'BBB']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [12265 19856  5962  1556   937] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['CCC', 'EEE', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [12265 19856  5962  1556   937] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['BBB', 'CCC', 'DDD', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 1130  8729 18832  8970  4426] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['CCC', 'FFF', 'FFF', 'GGG', 'BBB']
# [BI_GRAPH] 7, 6, 5, 4, 3 [ 9322 22532 25544 32255  7972] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['DDD', 'BBB', 'DDD', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16433  6000 14324 17928 17667] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['DDD', 'FFF', 'CCC', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [18710 29213 10397 15565 27912] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['CCC', 'FFF', 'GGG', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10509 24511 30900  3233 18655] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['DDD', 'FFF', 'CCC', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13199 23089 11445 10006  4961] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['BBB', 'GGG', 'EEE', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 10, 0, 0 [ 3565 32040 20420 24946 11661] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['FFF', 'GGG', 'FFF', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22433 32580 25631 24868 12357] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['DDD', 'CCC', 'BBB', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [15035 10714  8536 17445 26240] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['FFF', 'DDD', 'EEE', 'EEE', 'EEE']
# [BI_GRAPH] 10, 10, 10, 0, 0 [29246 15050 22042 20880 20234] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['FFF', 'BBB', 'DDD', 'CCC', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [23355  1121 18547  8812 21389] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['FFF', 'BBB', 'GGG', 'DDD', 'CCC']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [23860  8265 31271 16869  9728] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['FFF', 'BBB', 'GGG', 'BBB', 'FFF']
# Retrying...
# [BI_GRAPH] 10, 10, 8, 0, 0 [22890  5170 30200  7869 27773] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['CCC', 'BBB', 'GGG', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [12357  3565 32255 32301 17667] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['EEE', 'BBB', 'BBB', 'DDD', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [19856  5962  1121 13153 22890] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'EEE', 'FFF', 'FFF', 'DDD']
# [BI_GRAPH] 0, 10, 0, 0, 0 [18547 20880 24946 23860 17445] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['BBB', 'FFF', 'GGG', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7869 24868 31334 25544  8265] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['FFF', 'DDD', 'FFF', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25532 17304 23089 26240 10006] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['BBB', 'DDD', 'CCC', 'CCC', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  937 13199  9344 12265 32040] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['FFF', 'CCC', 'FFF', 'AAA', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [29213 10509 24511   623  7972] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['GGG', 'DDD', 'FFF', 'FFF', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31094 14324 23776 27287 30200] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['FFF', 'CCC', 'CCC', 'CCC', 'FFF']
# [BI_GRAPH] 0, 1, 1, 1, 1 [23355  8970 10714  8729 26610] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['CCC', 'AAA', 'BBB', 'CCC', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [11298   321  6549 11445 30900] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['DDD', 'BBB', 'GGG', 'BBB', 'CCC']
# [BI_GRAPH] 2, 3, 4, 5, 6 [15565  5170 32218  6552 11661] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['DDD', 'BBB', 'GGG', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16869  5896 31271  1556 15050] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['BBB', 'FFF', 'EEE', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 10, 0, 0 [ 4961 23362 22243 25631 15035] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['EEE', 'FFF', 'CCC', 'FFF', 'GGG']
# [BI_GRAPH] 10, 0, 0, 0, 0 [22042 27912  9322 29246 32580] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['FFF', 'DDD', 'BBB', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27773 18710  2859  8812 25432] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['BBB', 'FFF', 'BBB', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 1130 22532  6000 18832  8134] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['DDD', 'BBB', 'DDD', 'AAA', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [17928  2418 18655    11  8536] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['EEE', 'BBB', 'CCC', 'FFF', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20134  4426 10397 22433  8805] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['CCC', 'BBB', 'EEE', 'CCC', 'EEE']
# [BI_GRAPH] 0, 0, 10, 0, 10 [10936  3233 20234  9728 20420] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['CCC', 'EEE', 'BBB', 'DDD', 'DDD']
# [BI_GRAPH] 0, 10, 0, 0, 0 [10587 21389  5229 16433 16577] What is the count of rows with column 'code_module' equal to 'EEE'?
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: overflow encountered in scalar add
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: divide by zero encountered in scalar divide
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: overflow encountered in scalar add
#   b_j += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: divide by zero encountered in scalar divide
#   b_j += targets_all[target] / g.node_map[target].payload
# EEE | 3 / 10
# Running random...
# Running optimum...
# Running warmup...
# chunk:  [24737 27240 31616 20191]
# [Naive] related row indices:   The number of rows
# chunk:  [30605 25912 14151 10534]
# [Naive] related row indices:   The dataset you pro
# chunk:  [25857  3829  4311 29904]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [13397  9017 15365 22013]
# [Naive] related row indices:   The number of rows
# chunk:  [ 5138 26930 23954   494]
# [Naive] related row indices:   There are no rows i
# chunk:  [18394 21200 25155 30656]
# [Naive] related row indices:   The number of rows
# chunk:  [14598 26417  3428 18266]
# [Naive] related row indices:   There are no rows i
# chunk:  [12271 12021 22964  3000]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [20048  6615  9458 14512]
# [Naive] related row indices:   The list of indices
# chunk:  [ 3465 25574 17563 24121]
# [Naive] related row indices:   To answer your quer
# chunk:  [ 4972  3863 29003 30854]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [18712  9498  3510  7860]
# [Naive] related row indices:   There are no rows i
# chunk:  [31527  3152 25673  9682]
# [Naive] related row indices:   The provided datase
# chunk:  [15318 10882 27904 12937]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [11028 12838 14936 27474]
# [Naive] related row indices:   The dataset you pro
# chunk:  [25221  2802 28641 20331]
# [Naive] related row indices:   The query asks for
# chunk:  [26324  7267  4503  6774]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 4827  6001  5576 17881]
# [Naive] related row indices:   There are no rows i
# chunk:  [30618 14043 17607 17860]
# [Naive] related row indices:   There are no rows i
# chunk:  [22803 18218 19784 14658]
# [Naive] related row indices:   The number of rows
# chunk:  [17309 26779 11710 13288]
# [Naive] related row indices:   There are no rows i
# chunk:  [ 2222 25398  3555 29599]
# [Naive] related row indices:   There are 0 rows in
# chunk:  [ 6209  4777 32360 14077]
# [Naive] related row indices:   There are no rows i
# chunk:  [20743 31009  6940 23765]
# [Naive] related row indices:   The number of rows
# chunk:  [27406   836 26397  4176]
# [Naive] related row indices:   There are no rows i
# Run Bigraph...
# [BI_GRAPH] For query: What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 1 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['BBB', 'BBB', 'BBB', 'FFF', 'DDD']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [ 4176  4972  7267 23765 18218] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['BBB', 'BBB', 'BBB', 'FFF', 'DDD']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 4176  4972  7267 23765 18218] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['BBB', 'EEE', 'EEE', 'BBB', 'FFF']
# [BI_GRAPH] 0, 10, 10, 0, 0 [ 3000 19784 20743  2802 22803] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['CCC', 'FFF', 'FFF', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [12271 25221 25574 27474 27406] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['BBB', 'DDD', 'DDD', 'DDD', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 4827 18266 18712 14077 11028] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['FFF', 'DDD', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [29904 15365  6001  3152  9458] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['BBB', 'GGG', 'FFF', 'FFF', 'EEE']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [ 6615 30854 26930 26779 20191] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['BBB', 'GGG', 'FFF', 'FFF', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [ 6615 30854 26930 26779 20191] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['GGG', 'FFF', 'FFF', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [30656 25155 29599 25673 13397] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['DDD', 'FFF', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 2, 3, 1, 4, 0 [14043 24121  6940  4311  9498] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['DDD', 'DDD', 'CCC', 'DDD', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [17607 14598 10534 13288 30605] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['DDD', 'DDD', 'EEE', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 10, 0, 0 [17881 17309 20048  9017 24737] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['BBB', 'BBB', 'BBB', 'EEE', 'BBB']
# [BI_GRAPH] 0, 0, 0, 10, 0 [ 3428  5138  3863 20331  3555] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['AAA', 'FFF', 'GGG', 'CCC', 'CCC']
# [BI_GRAPH] 0, 10, 0, 0, 0 [  494 25398 31009  9682 12937] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['DDD', 'FFF', 'BBB', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14658 27904  3465 26324  4777] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['BBB', 'CCC', 'CCC', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 3510 12838 12021   836 26397] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['BBB', 'FFF', 'CCC', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6774 25912 10882 27240  7860] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['GGG', 'GGG', 'FFF', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31527 30618 26417 32360 18394] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['BBB', 'EEE', 'FFF', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2222 22013 25857 23954  3829] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['FFF', 'GGG', 'DDD', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [22964 31616 14936 15318 29003] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['DDD', 'BBB', 'DDD', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14151  4503 17563 11710  6209] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['DDD', 'DDD', 'EEE', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [14512 17860 21200 28641  5576] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['FFF', 'FFF', 'FFF', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [26779 24121 27240 25155 23954] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['FFF', 'FFF', 'FFF', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25673 25398 29904 27474  6209] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['FFF', 'BBB', 'DDD', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [24737  4176 14077 14151  6001] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['CCC', 'BBB', 'FFF', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10534  3829 23765 15318  6774] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['EEE', 'DDD', 'BBB', 'BBB', 'GGG']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20191 13397  5138  4311 30618] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['EEE', 'FFF', 'FFF', 'CCC', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 0 [19784 25221 26417 11028 10882] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['BBB', 'CCC', 'BBB', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 3465 11710   836  2222 26324] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['GGG', 'FFF', 'GGG', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [31527 26930 31616 25857 29599] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['BBB', 'CCC', 'FFF', 'EEE', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 3428  9458 29003 20743  3510] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['DDD', 'DDD', 'BBB', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [18394 14043  3000 22964 17881] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['DDD', 'DDD', 'EEE', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 10, 0, 0 [17563 14936 22013  2802 28641] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['EEE', 'DDD', 'BBB', 'GGG', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [21200 18266  7860 31009 27904] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['FFF', 'GGG', 'BBB', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25574 30854  6615 12271 27406] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['BBB', 'GGG', 'GGG', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7267 30605 30656 14598 26397] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['DDD', 'BBB', 'BBB', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [14512  3152  4827  3863 12937] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['EEE', 'BBB', 'DDD', 'DDD', 'EEE']
# [BI_GRAPH] 10, 0, 0, 0, 10 [20331  4972 17607 18712 20048] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['BBB', 'CCC', 'CCC', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 4777  9017 12838 12021  4503] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['FFF', 'GGG', 'DDD', 'DDD', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [25912 32360 13288 17309  9682] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ...
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['FFF', 'CCC', 'EEE', 'EEE', 'FFF']
# [BI_GRAPH] 0, 0, 10, 10, 0 [29015 11001 20958 19518 25292] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['CCC', 'GGG', 'BBB', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [10359 31128  7287  4987 19260] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['DDD', 'BBB', 'BBB', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16319  1285  4223 18363 18892] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['DDD', 'CCC', 'FFF', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [19003 13000 25435 27059 25141] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['DDD', 'CCC', 'BBB', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 1, 0, 0 [13788 11271  3118 16404  7423] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['BBB', 'DDD', 'CCC', 'FFF', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 1010 16700 12092 27016 30126] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['BBB', 'DDD', 'CCC', 'CCC', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6942 16091 10072 12788 16968] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['DDD', 'FFF', 'BBB', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [18706 29556  2997 23468 22892] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['BBB', 'DDD', 'BBB', 'DDD', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 5280 15621  7753 16830 10645] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['EEE', 'EEE', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20161 22063  3277  1760  3366] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['CCC', 'DDD', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 0, 10, 5, 5, 5 [10894 15308  6823  4139  7160] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['EEE', 'FFF', 'FFF', 'DDD', 'DDD']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20474 26280 27931 17847 16654] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['CCC', 'FFF', 'DDD', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [12257 26219 18760 29920 11584] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['AAA', 'CCC', 'DDD', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  386 11736 13116  1423  8255] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['FFF', 'EEE', 'DDD', 'CCC', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [29862 21277 19003 10072  1120] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['FFF', 'BBB', 'DDD', 'BBB', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [28065  1285 17847  4987 22892] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'CCC', 'FFF', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [19260 12871 27059  5226  2221] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['FFF', 'DDD', 'AAA', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [26219 13788   628 25292 11584] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['EEE', 'CCC', 'BBB', 'DDD', 'BBB']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [21228 12092  7753 15308  6942] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['EEE', 'CCC', 'BBB', 'DDD', 'BBB']
# [BI_GRAPH] 10, 0, 0, 0, 10 [21228 12092  7753 15308  6942] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['DDD', 'BBB', 'DDD', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13116  1760 16830 27255  3277] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['BBB', 'DDD', 'EEE', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 10, 0, 0 [ 3141 16404 20958 26280 18760] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['CCC', 'DDD', 'BBB', 'BBB', 'BBB']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [11001 18363  4223  7287  5491] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['CCC', 'DDD', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [11001 18363  4223  7287  5491] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['BBB', 'CCC', 'EEE', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 4139 10645 22063 25435 12788] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['EEE', 'BBB', 'BBB', 'CCC', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [19518  3803  2997 10359 23468] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['BBB', 'FFF', 'FFF', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6823 25914 27676 18706  3118] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['DDD', 'BBB', 'CCC', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16968  2956 11942 30126 15621] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['CCC', 'BBB', 'EEE', 'GGG', 'FFF']
# [BI_GRAPH] 0, 0, 10, 0, 0 [10894  7160 20764 31128 29920] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['FFF', 'BBB', 'BBB', 'DDD', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [23939  1423  1010 16654 26305] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['FFF', 'EEE', 'EEE', 'CCC', 'DDD']
# [BI_GRAPH] 0, 10, 10, 0, 0 [27931 21952 21527 10361 16319] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['DDD', 'AAA', 'DDD', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13568   386 18421  7423  8255] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['FFF', 'FFF', 'DDD', 'DDD', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [29015 27940 18892 14298 13000] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['CCC', 'FFF', 'FFF', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [11736 27016 25141  5280 11271] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['DDD', 'BBB', 'EEE', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16700  5021 20474 13948 16091] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['BBB', 'CCC', 'CCC', 'EEE', 'FFF']
# [BI_GRAPH] 0, 0, 0, 10, 0 [ 3366 12257  9185 20161 29556] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['CCC', 'FFF', 'BBB', 'CCC', 'DDD']
# [BI_GRAPH] 0, 5, 0, 0, 0 [10072 29015  7160 12871 14298] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['BBB', 'CCC', 'EEE', 'FFF', 'FFF']
# Retrying...
# NO LIST IN OUTPUT
# [BI_GRAPH] None [ 1285 11942 20161 27059 25435] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['BBB', 'CCC', 'EEE', 'FFF', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 1285 11942 20161 27059 25435] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['BBB', 'BBB', 'FFF', 'DDD', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7287  1120 23939 18892 16968] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['DDD', 'DDD', 'FFF', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16319 18706 25914  3366 13788] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['CCC', 'CCC', 'FFF', 'DDD', 'CCC']
# NO LIST IN OUTPUT
# [BI_GRAPH] None [12257 13000 29862 19003 12092] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] Error output:  expected string or bytes-like object, got 'NoneType'
# ['CCC', 'CCC', 'FFF', 'DDD', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [12257 13000 29862 19003 12092] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['BBB', 'CCC', 'BBB', 'EEE', 'BBB']
# [BI_GRAPH] 0, 0, 0, 10, 0 [ 3803 10359  7753 19518  3277] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['FFF', 'BBB', 'FFF', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27940  1010 25292  4223 16700] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['EEE', 'DDD', 'EEE', 'CCC', 'DDD']
# [BI_GRAPH] 10, 0, 10, 0, 0 [20958 17847 21228 10645 16830] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['FFF', 'DDD', 'DDD', 'CCC', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [26305 16404 18421 10361 19260] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['FFF', 'EEE', 'EEE', 'FFF', 'BBB']
# [BI_GRAPH] 0, 10, 10, 0, 0 [29556 21277 21952 29920  6823] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['DDD', 'FFF', 'BBB', 'AAA', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [13116 22892  1760   386 13948] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['EEE', 'GGG', 'FFF', 'BBB', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20764 31128 28065  4987 10894] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['BBB', 'FFF', 'DDD', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 5280 25141 15621  5021 13568] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['BBB', 'DDD', 'FFF', 'CCC', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8255 15308 23468 12788 18363] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['FFF', 'FFF', 'DDD', 'FFF', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27016 27255 16654 27931  2956] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['FFF', 'EEE', 'BBB', 'BBB', 'BBB']
# [BI_GRAPH] 0, 10, 0, 0, 0 [26219 21527  5226  6942  7423] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['BBB', 'FFF', 'EEE', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [ 2997 26280 20474 11001  3141] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['CCC', 'CCC', 'EEE', 'CCC', 'BBB']
# [BI_GRAPH] 0, 0, 10, 0, 0 [11584 11736 22063  9185  2221] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['AAA', 'DDD', 'BBB', 'BBB', 'GGG']
# [BI_GRAPH] 0, 0, 0, 0, 0 [  628 16091  4139  5491 30126] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['FFF', 'CCC', 'BBB', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27676 11271  1423  3118 18760] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 4 shuffles
# [BI_GRAPH] 1 / 20 batches
# ['FFF', 'FFF', 'CCC', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [27059 29920 10072  1285  7160] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 2 / 20 batches
# ['FFF', 'CCC', 'CCC', 'BBB', 'BBB']
# Retrying...
# [BI_GRAPH] 0, 0, 0, 0, 0 [25435 12092 11001  6823  2956] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 3 / 20 batches
# ['DDD', 'FFF', 'AAA', 'BBB', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [16091 22892   386  3366 16654] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 4 / 20 batches
# ['FFF', 'BBB', 'CCC', 'BBB', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [29015  3803 12871  3277 22063] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 5 / 20 batches
# ['BBB', 'BBB', 'BBB', 'FFF', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 6942  3118  1423 23939 14298] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 6 / 20 batches
# ['BBB', 'BBB', 'DDD', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 1760  4987 18760 11736 27255] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 7 / 20 batches
# ['DDD', 'DDD', 'CCC', 'DDD', 'DDD']
# [BI_GRAPH] 0, 3, 0, 2, 0 [15308 16700 10645 17847 13788] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 8 / 20 batches
# ['FFF', 'CCC', 'EEE', 'CCC', 'FFF']
# [BI_GRAPH] 0, 0, 10, 0, 0 [26305 12257 21228 10361 27676] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 9 / 20 batches
# ['EEE', 'FFF', 'FFF', 'DDD', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20764 25141 29556 16404 27931] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 10 / 20 batches
# ['BBB', 'BBB', 'DDD', 'DDD', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7753  4223 16830 18363  2221] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 11 / 20 batches
# ['EEE', 'DDD', 'FFF', 'AAA', 'FFF']
# [BI_GRAPH] 10, 0, 0, 0, 0 [21277 13948 27016   628 28065] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 12 / 20 batches
# ['BBB', 'DDD', 'DDD', 'GGG', 'DDD']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 2997 19003 15621 30126 18892] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 13 / 20 batches
# ['BBB', 'BBB', 'CCC', 'FFF', 'EEE']
# [BI_GRAPH] 0, 0, 0, 0, 10 [ 5021  4139 11942 26280 21527] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 14 / 20 batches
# ['EEE', 'BBB', 'BBB', 'CCC', 'DDD']
# [BI_GRAPH] 10, 0, 0, 0, 0 [20161  5280  5491 12788 16968] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 15 / 20 batches
# ['BBB', 'FFF', 'FFF', 'FFF', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 8255 26219 25914 29862  9185] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 16 / 20 batches
# ['BBB', 'DDD', 'DDD', 'BBB', 'BBB']
# [BI_GRAPH] 0, 0, 0, 0, 0 [ 7287 18706 13116  1010  5226] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 17 / 20 batches
# ['GGG', 'CCC', 'BBB', 'FFF', 'EEE']
# [BI_GRAPH] 10, 10, 10, 9, 8 [31128 10359  7423 23468 20958] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 18 / 20 batches
# ['EEE', 'EEE', 'DDD', 'FFF', 'CCC']
# [BI_GRAPH] 10, 0, 0, 0, 10 [20474 19518 13568 27940 10894] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 19 / 20 batches
# ['DDD', 'BBB', 'DDD', 'BBB', 'CCC']
# [BI_GRAPH] 0, 0, 0, 0, 0 [19260  1120 18421  3141 11271] What is the count of rows with column 'code_module' equal to 'EEE'?
# [BI_GRAPH] 20 / 20 batches
# ['CCC', 'EEE', 'CCC', 'FFF', 'DDD']
# [BI_GRAPH] 0, 10, 0, 0, 0 [13000 21952 11584 25292 16319] What is the count of rows with column 'code_module' equal to 'EEE'?
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: overflow encountered in scalar add
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: divide by zero encountered in scalar divide
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:124: RuntimeWarning: overflow encountered in scalar divide
#   y_i += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: overflow encountered in scalar add
#   b_j += targets_all[target] / g.node_map[target].payload
# /home/mohsen/llm/project/tasks/db/../../utils/bipartite.py:132: RuntimeWarning: divide by zero encountered in scalar divide
#   b_j += targets_all[target] / g.node_map[target].payload

# %%
final_result.to_csv(f"enroll_new_{model}.csv", index=0)

# %% [markdown]
# - Get the rank utilities to see if the result makes sense or not.

# %%
rank_utils = []

for i, row in final_result.iterrows():
    rank_utils.append(db_utils.rank_utility(df, row["reordered"], row["column"], row["value"]))

final_result["rank_utils"] = rank_utils

# %%
final_result[["algorithm", "rank_utils"]].groupby("algorithm").mean().reset_index()
# Out:
#   algorithm  rank_utils
# 0   bigraph    2.782025
# 1       opt    2.782025
# 2    random    0.648013
# 3    warmup    0.995564
